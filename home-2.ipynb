# %%
num_int =5
num_float =2.5
num_txt ='i am azhary'
print(num_int)
print(num_float)
print(num_txt)
# Out:
# 5
# 2.5
# i am azhary

# %%
num1=2
num2=5.3
sum=num1+num2
print(sum)
# Out:
# 7.3

# %%
name=input('Enter your name')
age=input('enter your age')
print(name)
print(age)
# Out:
# mohamed
# 38

# %%
Email=input('Enter your  E-mail')
password=input('Enter your password')
print('welcome')
# Out:
# welcome

# %%
num1=input('enter number1')
num2=input('enter number2')
num3=input('enter number3')
num1=float(num1)
num2=float(num2)
num3=float(num3)
sum=num1+num2+num3
print(sum)
# Out:
# 9.0

# %%
num1=float(input('enter number 1'))
num2=float(input('enter number2'))
num3=float(input('enter number 3'))
sum=num1+num2+num3
print(sum)
# Out:
# 6.0

# %%
x='i am data scientist'
print(x)
y=x
print(y + ' how  r you ')
print(y[2])
print(x[2:4:1])
print(y[5:9:1])
print(y[-1:-10:-1])
print(y[::1])
x.upper()
x.lower()
x.title()
x.upper()
# Out:
# i am data scientist
# i am data scientist how  r you
# a
# am
# data
# tsitneics
# i am data scientist
# 'I AM DATA SCIENTIST'

# %%
x=('i am data scientest')
x=x.strip()
print(x)
# Out:
# i am data scientest

# %%
x=('hi my name is mohamed')
x=x.upper()
print(x)
x=x.strip()
print(x)
# Out:
# HI MY NAME IS MOHAMED
# HI MY NAME IS MOHAMED

# %%
x=('i am data scientest')
y=('i am an ai engineer')
print(x+' , '+y)
# Out:
# i am data scientest , i am an ai engineer

# %%
x=str(input('enter the word'))
x[::-1]
# Out:
# 'demahom'

# %%
x=input('enter a word')
print(x[::-1])
# Out:
# demahom

# %%
x=input('enter a float number')
y=x.split('.')
print(y)
# Out:
# ['20', '5']
