# %%
def area(radius=1):
    c=2*3.14*radius
    a=3.14*radius**2
    print(c)
    print(a)
    return c,a

# %%
def calculator():
    print("Welcome to the simple calculator!")
    
   
    num1 = float(input("Enter the first number: "))
    operation = input("Enter the operation (+, -, *, /): ")
    num2 = float(input("Enter the second number: "))
    

    if operation == "+":
        result = num1 + num2
    elif operation == "-":
        result = num1 - num2
    elif operation == "*":
        result = num1 * num2
    elif operation == "/":
        if num2 == 0:
            return "Error: Division by zero is not allowed."
        result = num1 / num2
    else:
        return "Error: Invalid operation. Please choose +, -, *, or /."

    return f"The result of {num1} {operation} {num2} is {result}"


print(calculator())
# Out:
# Welcome to the simple calculator!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 26
#      21         return "Error: Invalid operation. Please choose +, -, *, or /."
#      23     return f"The result of {num1} {operation} {num2} is {result}"
# ---> 26 print(calculator())
#
# Cell In[14], line 7, in calculator()
#       5 num1 = float(input("Enter the first number: "))
#       6 operation = input("Enter the operation (+, -, *, /): ")
# ----> 7 num2 = float(input("Enter the second number: "))
#      10 if operation == "+":
#      11     result = num1 + num2
#
# ValueError: could not convert string to float: '2*2'

# %%
def range(index):
    l=[1, 2, 3, 4]
    try:
        return l[index]
    except Exception as e :
        return e
x=range(10)
print(x)
# Out:
# list index out of range

# %%
l = [1, 3, 3, 5, 5, 8, 9, 7, 10, 1]

occurrences = {}

for item in l:
    if item in occurrences:
        occurrences[item] += 1
    else:
        occurrences[item] = 1

print(occurrences)
# Out:
# {1: 2, 3: 2, 5: 2, 8: 1, 9: 1, 7: 1, 10: 1}

# %%
import random

def play_game():
    
    options = ["rock", "paper", "scissors"]
    
    while True:
        try:
            
            user_choice = input("Choose rock, paper, or scissors (or 'quit' to exit): ").lower().strip()
            if user_choice == "quit":
                print("Thanks for playing!")
                break
            if user_choice not in options:
                raise ValueError("Invalid choice. Please choose rock, paper, or scissors.")
            
            
            remaining = [opt for opt in options if opt != user_choice]
            computer_choice = random.choice(remaining)
            
            print(f"You chose: {user_choice}")
            print(f"Computer chose: {computer_choice}")
            
        
            if (user_choice == "rock" and computer_choice == "scissors") or \
               (user_choice == "scissors" and computer_choice == "paper") or \
               (user_choice == "paper" and computer_choice == "rock"):
                print("You win!")
            else:
                print("Computer wins!")
        
        except ValueError as e:
            print(f"Error: {e}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# Run the game
play_game()
# Out:
# Error: Invalid choice. Please choose rock, paper, or scissors.
# Thanks for playing!
